# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
data = pd.read_csv("linear-regression-dataset (2).csv")
data
# Out:
#     Hours  Practice  TeamWork  Scores
# 0     2.5       0.5       0.0      21
# 1     5.1       1.5       0.5      47
# 2     3.2       1.0       0.5      27
# 3     8.5       3.7       1.2      75
# 4     3.5       1.2       0.3      30
# 5     1.5       0.2       0.0      20
# 6     9.2       4.8       3.0      88
# 7     5.5       3.2       2.0      60
# 8     9.3       5.1       3.5      81
# 9     2.7       1.5       0.0      25
# 10    7.7       4.9       4.5      85
# 11    5.9       3.1       2.1      62
# 12    4.5       2.8       1.0      41
# 13    3.3       2.2       1.1      42
# 14    1.1       1.1       0.0      17
# 15    8.9       6.2       6.0      95
# 16    2.5       1.6       1.0      30
# 17    1.9       0.9       0.5      24
# 18    6.1       2.0       3.2      67
# 19    7.4       2.5       3.0      69
# 20    2.7       3.0       1.2      30
# 21    4.8       2.9       2.1      54
# 22    3.8       2.2       0.3      35
# 23    6.9       5.1       3.8      76
# ...

# %%
df = pd.DataFrame(data, columns = ["Hours", "Practice", "TeamWork", "Scores"])
df
# Out:
#     Hours  Practice  TeamWork  Scores
# 0     2.5       0.5       0.0      21
# 1     5.1       1.5       0.5      47
# 2     3.2       1.0       0.5      27
# 3     8.5       3.7       1.2      75
# 4     3.5       1.2       0.3      30
# 5     1.5       0.2       0.0      20
# 6     9.2       4.8       3.0      88
# 7     5.5       3.2       2.0      60
# 8     9.3       5.1       3.5      81
# 9     2.7       1.5       0.0      25
# 10    7.7       4.9       4.5      85
# 11    5.9       3.1       2.1      62
# 12    4.5       2.8       1.0      41
# 13    3.3       2.2       1.1      42
# 14    1.1       1.1       0.0      17
# 15    8.9       6.2       6.0      95
# 16    2.5       1.6       1.0      30
# 17    1.9       0.9       0.5      24
# 18    6.1       2.0       3.2      67
# 19    7.4       2.5       3.0      69
# 20    2.7       3.0       1.2      30
# 21    4.8       2.9       2.1      54
# 22    3.8       2.2       0.3      35
# 23    6.9       5.1       3.8      76
# ...

# %%
df.describe()
# Out:
#            Hours   Practice   TeamWork     Scores
# count  25.000000  25.000000  25.000000  25.000000
# mean    5.052000   2.760000   1.812000  51.480000
# std     2.586523   1.722885   1.697871  25.286887
# min     1.100000   0.200000   0.000000  17.000000
# 25%     2.700000   1.500000   0.500000  30.000000
# 50%     4.800000   2.500000   1.200000  47.000000
# 75%     7.400000   3.700000   3.000000  75.000000
# max     9.300000   6.200000   6.000000  95.000000

# %%
df.dropna(inplace = True)

# %%
x = pd.DataFrame(data, columns = ["Hours","Practice","TeamWork"])
y = data["Scores"].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
a = x_test.Hours
b = y_test
c = x_test.Hours
d = y_pred
plt.scatter(a,b)
plt.scatter(c,d)
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.grid()

# %%
a = x_test
b = y_test
plt.scatter(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-bcbb696a6f56> in <module>
#       1 a = x_test
#       2 b = y_test
# ----> 3 plt.scatter(a,b)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
#couldnt be plot x_test with y_pred and y_test beacuse the size of them are not the same
#x and y must be the same size

x_test
# Out:
#     Hours  Practice  TeamWork
# 5     1.5       0.2       0.0
# 2     3.2       1.0       0.5
# 19    7.4       2.5       3.0
# 16    2.5       1.6       1.0
# 11    5.9       3.1       2.1

# %%
y_pred
# Out:
# array([[18.53398612],
#        [32.56779011],
#        [73.67221622],
#        [30.34124366],
#        [58.9194762 ]])

# %%
y_test
# Out:
# array([[20],
#        [27],
#        [69],
#        [30],
#        [62]], dtype=int64)

# %%
x_test.insert(3, "y_test", y_test)

# %%
x_test.insert(4, "y_pred", y_pred)
x_test
# Out:
#     Hours  Practice  TeamWork  y_test     y_pred
# 5     1.5       0.2       0.0      20  18.533986
# 2     3.2       1.0       0.5      27  32.567790
# 19    7.4       2.5       3.0      69  73.672216
# 16    2.5       1.6       1.0      30  30.341244
# 11    5.9       3.1       2.1      62  58.919476

# %%
df2 = x_test.sort_values(by = ["Hours"])
df2
# Out:
#     Hours  Practice  TeamWork  y_test     y_pred
# 5     1.5       0.2       0.0      20  18.533986
# 16    2.5       1.6       1.0      30  30.341244
# 2     3.2       1.0       0.5      27  32.567790
# 11    5.9       3.1       2.1      62  58.919476
# 19    7.4       2.5       3.0      69  73.672216

# %%
a = df2.Hours
b = df2.y_test
c = df2.Hours
d = df2.y_pred
plt.scatter(a,b)
plt.plot(c,d, color = "red")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.grid()

# %%
a = df2.Practice
b = df2.y_test
c = df2.Practice
d = df2.y_pred
plt.scatter(a,b)
plt.plot(c,d, color = "red")
plt.xlabel("Practice")
plt.ylabel("Scores")
plt.grid()

# %%
a = df2.TeamWork
b = df2.y_test
c = df2.TeamWork
d = df2.y_pred
plt.scatter(a,b)
plt.plot(c,d, color = "red")
plt.xlabel("TeamWork")
plt.ylabel("Scores")
plt.grid()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [8.37366712]
# [[ 6.77781271 -0.03200033  5.07424529]]

# %%
# [Hours = 6.77781271, Practice = -0.03200033, TeamWork = 5.07424529, Scores = 8.37366712]

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("test")
plt.ylabel("prediction")
plt.grid()

# %%
compare = pd.DataFrame({"Actual": y_test.flatten(), "Predict":y_pred.flatten()})
compare
# Out:
#    Actual    Predict
# 0      20  18.533986
# 1      27  32.567790
# 2      69  73.672216
# 3      30  30.341244
# 4      62  58.919476

# %%
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: ", metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  3.025557534472642
# Mean Squared Error:  12.9170323895091
# Root Mean Squared Error:  3.5940273217532863
# R2 Score:  0.9674009883164014

# %%
#compare multi variable linear regression with simple linear regression in this projec
#with the same project with one variable in simple linear regression
#the four samples from five in multi variables in actual and predict part are better than one variable (simple linear regression project) 
# we also compare Errors and Scores in two project and still multi variable in this project is better that simple regression

# %%
df2
# Out:
#     Hours  Practice  TeamWork  y_test     y_pred
# 5     1.5       0.2       0.0      20  18.533986
# 16    2.5       1.6       1.0      30  30.341244
# 2     3.2       1.0       0.5      27  32.567790
# 11    5.9       3.1       2.1      62  58.919476
# 19    7.4       2.5       3.0      69  73.672216

# %%
df2 = pd.DataFrame({"Hours": [3.5,5,12], "Practice":[2,3,6], "TeamWork":[0,1,3], "Scores":[10,11,12]})
df2
# Out:
#    Hours  Practice  TeamWork  Scores
# 0    3.5         2         0      10
# 1    5.0         3         1      11
# 2   12.0         6         3      12

# %%
df
# Out:
#     Hours  Practice  TeamWork  Scores
# 0     2.5       0.5       0.0      21
# 1     5.1       1.5       0.5      47
# 2     3.2       1.0       0.5      27
# 3     8.5       3.7       1.2      75
# 4     3.5       1.2       0.3      30
# 5     1.5       0.2       0.0      20
# 6     9.2       4.8       3.0      88
# 7     5.5       3.2       2.0      60
# 8     9.3       5.1       3.5      81
# 9     2.7       1.5       0.0      25
# 10    7.7       4.9       4.5      85
# 11    5.9       3.1       2.1      62
# 12    4.5       2.8       1.0      41
# 13    3.3       2.2       1.1      42
# 14    1.1       1.1       0.0      17
# 15    8.9       6.2       6.0      95
# 16    2.5       1.6       1.0      30
# 17    1.9       0.9       0.5      24
# 18    6.1       2.0       3.2      67
# 19    7.4       2.5       3.0      69
# 20    2.7       3.0       1.2      30
# 21    4.8       2.9       2.1      54
# 22    3.8       2.2       0.3      35
# 23    6.9       5.1       3.8      76
# ...

# %%
df3 = df.append(df2)
df3
# Out:
#     Hours  Practice  TeamWork  Scores
# 0     2.5       0.5       0.0      21
# 1     5.1       1.5       0.5      47
# 2     3.2       1.0       0.5      27
# 3     8.5       3.7       1.2      75
# 4     3.5       1.2       0.3      30
# 5     1.5       0.2       0.0      20
# 6     9.2       4.8       3.0      88
# 7     5.5       3.2       2.0      60
# 8     9.3       5.1       3.5      81
# 9     2.7       1.5       0.0      25
# 10    7.7       4.9       4.5      85
# 11    5.9       3.1       2.1      62
# 12    4.5       2.8       1.0      41
# 13    3.3       2.2       1.1      42
# 14    1.1       1.1       0.0      17
# 15    8.9       6.2       6.0      95
# 16    2.5       1.6       1.0      30
# 17    1.9       0.9       0.5      24
# 18    6.1       2.0       3.2      67
# 19    7.4       2.5       3.0      69
# 20    2.7       3.0       1.2      30
# 21    4.8       2.9       2.1      54
# 22    3.8       2.2       0.3      35
# 23    6.9       5.1       3.8      76
# ...

# %%
train = df3.iloc[:25]
test = df3.iloc[25:]

# %%
train
# Out:
#     Hours  Practice  TeamWork  Scores
# 0     2.5       0.5       0.0      21
# 1     5.1       1.5       0.5      47
# 2     3.2       1.0       0.5      27
# 3     8.5       3.7       1.2      75
# 4     3.5       1.2       0.3      30
# 5     1.5       0.2       0.0      20
# 6     9.2       4.8       3.0      88
# 7     5.5       3.2       2.0      60
# 8     9.3       5.1       3.5      81
# 9     2.7       1.5       0.0      25
# 10    7.7       4.9       4.5      85
# 11    5.9       3.1       2.1      62
# 12    4.5       2.8       1.0      41
# 13    3.3       2.2       1.1      42
# 14    1.1       1.1       0.0      17
# 15    8.9       6.2       6.0      95
# 16    2.5       1.6       1.0      30
# 17    1.9       0.9       0.5      24
# 18    6.1       2.0       3.2      67
# 19    7.4       2.5       3.0      69
# 20    2.7       3.0       1.2      30
# 21    4.8       2.9       2.1      54
# 22    3.8       2.2       0.3      35
# 23    6.9       5.1       3.8      76
# ...

# %%
test
# Out:
#    Hours  Practice  TeamWork  Scores
# 0    3.5       2.0       0.0      10
# 1    5.0       3.0       1.0      11
# 2   12.0       6.0       3.0      12

# %%
x_train = df3[["Hours","Practice","TeamWork"]][:25]
y_train = df3[["Scores"]][:25].values.reshape(-1,1)

# %%
x_test = df3[["Hours","Practice","TeamWork"]][25:]

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
print(y_pred)
# Out:
# [[ 32.29721684]
#  [ 47.52462159]
#  [104.79055067]]

# %%
#if we compare that numbers with y_pred of one variable in simple linear regression 
#we realize that all of these numbers are less and standard than single vaiable project in this part

# %%
# now we want to realize behibde the sence of linear regression equation and built the one

# %%
Y1 = 8.37366712 + (6.77781271 * 3.5) + (-0.03200033 * 2) + (5.07424529 * 0.0)
Y1
# Out:
# 32.032010945

# %%
# now we write the code of the  linear regression equation

# %%
Hours = float(input("THe hour is: "))
Practice = float(input("THe practice is: "))
TeamWork  = float(input("THe teamwork is: "))

print(8.37366712 + (6.77781271 * Hours) + (-0.03200033 * Practice) + (5.07424529 * TeamWork))
# Out:
# THe hour is: 3.5
# THe practice is: 2
# THe teamwork is: 0
# 32.032010945

# %%
Hours = float(input("THe hour is: "))
Practice = float(input("THe practice is: "))
TeamWork  = float(input("THe teamwork is: "))

print(8.37366712 + (6.77781271 * Hours) + (-0.03200033 * Practice) + (5.07424529 * TeamWork))
# Out:
# THe hour is: 5
# THe practice is: 3
# THe teamwork is: 1
# 47.24097497

# %%
Hours = float(input("THe hour is: "))
Practice = float(input("THe practice is: "))
TeamWork  = float(input("THe teamwork is: "))

print("Scores: ", 8.37366712 + (6.77781271 * Hours) + (-0.03200033 * Practice) + (5.07424529 * TeamWork))

# %%
# so we are consider 90 train and 10 test 90/10
# and 70/10 means 70 train and 30 test
#so after that compare these two with 80/20

# %%
x = pd.DataFrame(data, columns = ["Hours","Practice","TeamWork"])
y = data["Scores"].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.1, random_state = 0)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
compare1 = pd.DataFrame({"Actual": y_test.flatten(), "Predict":y_pred.flatten()})
compare1
# Out:
#    Actual    Predict
# 0      20  18.615571
# 1      27  32.698871
# 2      69  73.954079

# %%
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: ", metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  4.012459881659363
# Mean Squared Error:  19.64555937414963
# Root Mean Squared Error:  4.432331144459948
# R2 Score:  0.9580422319963582

# %%
# The result is that the efficiancy and accuracy of 80/20 is better that 90/10
# we examined two factores 
# 1)the distance between numbers is less in 80/20 this is good
# 2)the Errors are less than 90/10 and Scores is higher than 90/10

# %%
# now we examine 70/30

# %%
x = pd.DataFrame(data, columns = ["Hours","Practice","TeamWork"])
y = data["Scores"].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
compare2 = pd.DataFrame({"Actual": y_test.flatten(), "Predict":y_pred.flatten()})
compare2
# Out:
#    Actual    Predict
# 0      20  18.724430
# 1      27  32.733308
# 2      69  73.767490
# 3      30  30.298901
# 4      62  58.837718
# 5      35  35.602096
# 6      24  23.824775
# 7      86  83.320883

# %%
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: ", metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  2.336748632726377
# Mean Squared Error:  9.360889849339033
# Root Mean Squared Error:  3.0595571328770825
# R2 Score:  0.9823996900508917

# %%
# The result is that the efficiancy and accuracy of 70/30 is better that 80/20
# we examined two factores 
# 1)the distance between numbers is less in 70/30 this is good
# 2)the Errors in 70/30 are less than 80/20 and Scores is higher than 80/20

# %%
Hours2 = df.Hours**2

# %%
df
# Out:
#     Hours  Practice  TeamWork  Scores
# 0     2.5       0.5       0.0      21
# 1     5.1       1.5       0.5      47
# 2     3.2       1.0       0.5      27
# 3     8.5       3.7       1.2      75
# 4     3.5       1.2       0.3      30
# 5     1.5       0.2       0.0      20
# 6     9.2       4.8       3.0      88
# 7     5.5       3.2       2.0      60
# 8     9.3       5.1       3.5      81
# 9     2.7       1.5       0.0      25
# 10    7.7       4.9       4.5      85
# 11    5.9       3.1       2.1      62
# 12    4.5       2.8       1.0      41
# 13    3.3       2.2       1.1      42
# 14    1.1       1.1       0.0      17
# 15    8.9       6.2       6.0      95
# 16    2.5       1.6       1.0      30
# 17    1.9       0.9       0.5      24
# 18    6.1       2.0       3.2      67
# 19    7.4       2.5       3.0      69
# 20    2.7       3.0       1.2      30
# 21    4.8       2.9       2.1      54
# 22    3.8       2.2       0.3      35
# 23    6.9       5.1       3.8      76
# ...

# %%
df.insert(1,"Hours2", Hours2)
df
# Out:
#     Hours  Hours2  Practice  TeamWork  Scores
# 0     2.5    6.25       0.5       0.0      21
# 1     5.1   26.01       1.5       0.5      47
# 2     3.2   10.24       1.0       0.5      27
# 3     8.5   72.25       3.7       1.2      75
# 4     3.5   12.25       1.2       0.3      30
# 5     1.5    2.25       0.2       0.0      20
# 6     9.2   84.64       4.8       3.0      88
# 7     5.5   30.25       3.2       2.0      60
# 8     9.3   86.49       5.1       3.5      81
# 9     2.7    7.29       1.5       0.0      25
# 10    7.7   59.29       4.9       4.5      85
# 11    5.9   34.81       3.1       2.1      62
# 12    4.5   20.25       2.8       1.0      41
# 13    3.3   10.89       2.2       1.1      42
# 14    1.1    1.21       1.1       0.0      17
# 15    8.9   79.21       6.2       6.0      95
# 16    2.5    6.25       1.6       1.0      30
# 17    1.9    3.61       0.9       0.5      24
# 18    6.1   37.21       2.0       3.2      67
# ...

# %%
sinHour = np.sin((2*np.pi*df.Hours)/365)

# %%
df.insert(2,"sinH", sinHour)
df
# Out:
#     Hours  Hours2      sinH  Practice  TeamWork  Scores
# 0     2.5    6.25  0.043022       0.5       0.0      21
# 1     5.1   26.01  0.087680       1.5       0.5      47
# 2     3.2   10.24  0.055058       1.0       0.5      27
# 3     8.5   72.25  0.145799       3.7       1.2      75
# 4     3.5   12.25  0.060213       1.2       0.3      30
# 5     1.5    2.25  0.025818       0.2       0.0      20
# 6     9.2   84.64  0.157710       4.8       3.0      88
# 7     5.5   30.25  0.094537       3.2       2.0      60
# 8     9.3   86.49  0.159409       5.1       3.5      81
# 9     2.7    7.29  0.046462       1.5       0.0      25
# 10    7.7   59.29  0.132162       4.9       4.5      85
# 11    5.9   34.81  0.101389       3.1       2.1      62
# 12    4.5   20.25  0.077386       2.8       1.0      41
# 13    3.3   10.89  0.056776       2.2       1.1      42
# 14    1.1    1.21  0.018934       1.1       0.0      17
# 15    8.9   79.21  0.152608       6.2       6.0      95
# ...
