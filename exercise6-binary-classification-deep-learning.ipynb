# %% [markdown]
# <a href="https://www.kaggle.com/code/parisanahmadi/exercise6-binary-classification-deep-learning?scriptVersionId=102682595" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model =keras.Sequential([
    layers.BatchNormalization(input_shape = input_shape),
    layers.Dense(256, activation = "relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation = "relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation ="sigmoid")
    
])

# Check your answer
q_1.check()
# Out:
# 2022-08-06 18:19:26.566446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:26.688546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:26.689509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:26.691214: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-06 18:19:26.695760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:26.696572: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:26.697404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:28.974149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:28.975045: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:28.975717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-06 18:19:28.976318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
optimizer = "Adam",
loss = "binary_crossentropy",
metrics = ["binary_accuracy"],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# 2022-08-06 18:19:29.611049: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 175/175 [==============================] - 3s 7ms/step - loss: 0.4856 - binary_accuracy: 0.7699 - val_loss: 0.4320 - val_binary_accuracy: 0.7970
# Epoch 2/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4241 - binary_accuracy: 0.8012 - val_loss: 0.4010 - val_binary_accuracy: 0.8148
# Epoch 3/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.4090 - binary_accuracy: 0.8074 - val_loss: 0.3938 - val_binary_accuracy: 0.8172
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4009 - binary_accuracy: 0.8131 - val_loss: 0.3893 - val_binary_accuracy: 0.8185
# Epoch 5/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3972 - binary_accuracy: 0.8133 - val_loss: 0.3872 - val_binary_accuracy: 0.8205
# Epoch 6/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3923 - binary_accuracy: 0.8167 - val_loss: 0.3847 - val_binary_accuracy: 0.8248
# Epoch 7/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3884 - binary_accuracy: 0.8182 - val_loss: 0.3782 - val_binary_accuracy: 0.8256
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3850 - binary_accuracy: 0.8206 - val_loss: 0.3754 - val_binary_accuracy: 0.8297
# Epoch 9/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3824 - binary_accuracy: 0.8220 - val_loss: 0.3768 - val_binary_accuracy: 0.8284
# Epoch 10/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3794 - binary_accuracy: 0.8245 - val_loss: 0.3724 - val_binary_accuracy: 0.8303
# Epoch 11/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3773 - binary_accuracy: 0.8245 - val_loss: 0.3734 - val_binary_accuracy: 0.8273
# Epoch 12/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3735 - binary_accuracy: 0.8266 - val_loss: 0.3723 - val_binary_accuracy: 0.8293
# Epoch 13/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3714 - binary_accuracy: 0.8288 - val_loss: 0.3687 - val_binary_accuracy: 0.8318
# Epoch 14/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3701 - binary_accuracy: 0.8290 - val_loss: 0.3648 - val_binary_accuracy: 0.8353
# Epoch 15/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3674 - binary_accuracy: 0.8286 - val_loss: 0.3665 - val_binary_accuracy: 0.8327
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3668 - binary_accuracy: 0.8298 - val_loss: 0.3649 - val_binary_accuracy: 0.8338
# Epoch 17/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3636 - binary_accuracy: 0.8321 - val_loss: 0.3618 - val_binary_accuracy: 0.8365
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3626 - binary_accuracy: 0.8315 - val_loss: 0.3635 - val_binary_accuracy: 0.8334
# Epoch 19/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3610 - binary_accuracy: 0.8317 - val_loss: 0.3617 - val_binary_accuracy: 0.8355
# Epoch 20/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3591 - binary_accuracy: 0.8331 - val_loss: 0.3611 - val_binary_accuracy: 0.8359
# Epoch 21/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3590 - binary_accuracy: 0.8341 - val_loss: 0.3584 - val_binary_accuracy: 0.8381
# Epoch 22/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3570 - binary_accuracy: 0.8344 - val_loss: 0.3579 - val_binary_accuracy: 0.8365
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3550 - binary_accuracy: 0.8356 - val_loss: 0.3563 - val_binary_accuracy: 0.8395
# Epoch 24/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3532 - binary_accuracy: 0.8369 - val_loss: 0.3569 - val_binary_accuracy: 0.8394
# Epoch 25/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3524 - binary_accuracy: 0.8358 - val_loss: 0.3580 - val_binary_accuracy: 0.8391
# Epoch 26/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3512 - binary_accuracy: 0.8363 - val_loss: 0.3565 - val_binary_accuracy: 0.8385
# Epoch 27/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3516 - binary_accuracy: 0.8367 - val_loss: 0.3557 - val_binary_accuracy: 0.8404
# Epoch 28/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3500 - binary_accuracy: 0.8377 - val_loss: 0.3549 - val_binary_accuracy: 0.8399
# Epoch 29/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3488 - binary_accuracy: 0.8390 - val_loss: 0.3545 - val_binary_accuracy: 0.8394
# Epoch 30/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3469 - binary_accuracy: 0.8399 - val_loss: 0.3524 - val_binary_accuracy: 0.8415
# Epoch 31/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3470 - binary_accuracy: 0.8399 - val_loss: 0.3562 - val_binary_accuracy: 0.8397
# Epoch 32/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3464 - binary_accuracy: 0.8394 - val_loss: 0.3544 - val_binary_accuracy: 0.8387
# Epoch 33/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3444 - binary_accuracy: 0.8398 - val_loss: 0.3552 - val_binary_accuracy: 0.8390
# Epoch 34/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3436 - binary_accuracy: 0.8411 - val_loss: 0.3519 - val_binary_accuracy: 0.8403
# Epoch 35/200
# 175/175 [==============================] - 1s 4ms/step - loss: 0.3427 - binary_accuracy: 0.8412 - val_loss: 0.3536 - val_binary_accuracy: 0.8393
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
